# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

if not os.path.exists('/content/drive/MyDrive/Group project/cleaned_data'):
    os.makedirs('/content/drive/MyDrive/Group project/cleaned_data')

# %%
df_restaurants = pd.read_csv('/content/drive/MyDrive/Group project/data/restaurants.csv')
df_restaurants.head()
# Out:
#                             id                      name type_of_food  \
# 0  ChIJOaDRwjtRqEcRnkLvxNMuZdw  Coréen Restaurant Berlin       Korean
# 1  ChIJs-hQDcRRqEcR3HX3Tir_5M0       Mmaah - Eat Korean!       Korean
# 2  ChIJ7Y1MwOZRqEcRqYdK1VDzYx4                soopoollim       Korean
# 3  ChIJMferFeJRqEcR4ILthWXklLA             YamYam Berlin       Korean
# 4  ChIJB39gGgBRqEcR81n8a7nl0fY                   Gippeum       Korean
#
#                                              address  \
# 0               Torstraße 179, 10115 Berlin, Germany
# 1  Elisabeth-Schwarzhaupt-Platz 5, 10115 Berlin, ...
# 2             Ackerstraße 149, 10115 Berlin, Germany
# 3     Alte Schönhauser Str. 6, 10119 Berlin, Germany
# 4          Chausseestraße 122, 10115 Berlin, Germany
#
#                             short_address  \
# 0                   Torstraße 179, Berlin
# 1  Elisabeth-Schwarzhaupt-Platz 5, Berlin
# 2                 Ackerstraße 149, Berlin
# 3         Alte Schönhauser Str. 6, Berlin
# 4              Chausseestraße 122, Berlin
#
#                                         location district        lat  \
# 0         {'lat': 52.5287438, 'lng': 13.3939059}    Mitte  52.528744
# 1         {'lat': 52.5325433, 'lng': 13.3879003}    Mitte  52.532543
# 2         {'lat': 52.5315761, 'lng': 13.3961477}    Mitte  52.531576
# 3         {'lat': 52.5275836, 'lng': 13.4082387}    Mitte  52.527584
# 4  {'lat': 52.52920899999999, 'lng': 13.3841791}    Mitte  52.529209
#
#          lng national_phone  ...  \
# 0  13.393906   030 28883888  ...
# 1  13.387900  0176 75824086  ...
# 2  13.396148            NaN  ...
# 3  13.408239   030 24632485  ...
# 4  13.384179            NaN  ...
#
#                                accessibility_options  \
# 0  {'wheelchairAccessibleParking': False, 'wheelc...
# 1             {'wheelchairAccessibleEntrance': True}
# 2                                                NaN
# 3  {'wheelchairAccessibleParking': False, 'wheelc...
# 4                                                NaN
#
#                                      parking_options  \
# 0  {'freeParkingLot': False, 'paidParkingLot': Tr...
# 1                                                NaN
# 2                        {'paidStreetParking': True}
# 3                        {'paidStreetParking': True}
# 4                        {'paidStreetParking': True}
#
#                                      payment_options  takeout delivery  \
# 0  {'acceptsCreditCards': True, 'acceptsDebitCard...     True    False
# 1  {'acceptsCreditCards': True, 'acceptsDebitCard...     True     True
# 2  {'acceptsCreditCards': True, 'acceptsDebitCard...     True      NaN
# 3  {'acceptsCreditCards': False, 'acceptsDebitCar...     True     True
# 4                                                NaN     True      NaN
#
#   dine_in                                    google_maps_uri  \
# 0    True  https://maps.google.com/?cid=15881151148068913...
# 1    True  https://maps.google.com/?cid=14836263629643806...
# 2    True  https://maps.google.com/?cid=21898613723335576...
# 3    True  https://maps.google.com/?cid=12724045971918258...
# 4    True  https://maps.google.com/?cid=17785248988006210...
#
#   current_popularity                                       populartimes  \
# 0               75.0  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 1                NaN  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 2                NaN                                                NaN
# 3                NaN  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 4                NaN                                                NaN
#
#                                            time_wait
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 4                                                NaN
#
# [5 rows x 30 columns]

# %%
df_restaurants.shape
# Out:
# (3434, 30)

# %%
# Drop unnecessary columns
df_restaurants.drop(columns=["id", "address", "short_address", "location",
                             "national_phone","international_phone", "website",
                             "business_status", "current_opening_hours",
                             "editorial_summary", "google_maps_uri",
                             "current_popularity", "payment_options",
                             "time_wait", "types", "regular_opening_hours",
                             "lat", "lng"],
                    inplace=True, errors='ignore')
df_restaurants.columns
# Out:
# Index(['name', 'type_of_food', 'district', 'rating', 'total_ratings',
#        'price_level', 'accessibility_options', 'parking_options', 'takeout',
#        'delivery', 'dine_in', 'populartimes'],
#       dtype='object')

# %%
df_restaurants.isna().sum().sort_values(ascending=False)
# Out:
# price_level              1285
# populartimes             1031
# parking_options          1012
# accessibility_options     636
# delivery                  490
# takeout                   238
# dine_in                    68
# rating                     22
# total_ratings              22
# district                    0
# name                        0
# type_of_food                0
# dtype: int64

# %%
# Dealing with missing values
df_restaurants.dropna(subset=['rating', 'total_ratings'], inplace=True)

df_restaurants.fillna({"price_level": "NO_PRICE_DATA", "dine_in": "FALSE",
                      "takeout": "FALSE", "delivery": "FALSE"}, inplace=True)

# %%
def safe_json_loads(x):
    if pd.isna(x):
        return None

    try:
        x = (
            x.replace("'", '"')
             .replace("True", "true")
             .replace("False", "false")
             .replace("None", "null")
        )
        return json.loads(x)
    except json.JSONDecodeError:
        print("Invalid JSON:", x)
        return None

def pick(d, key):
    return d.get(key, False) if isinstance(d, dict) else False

# %%
if 'accessibility_options' in df_restaurants.columns:
    df_restaurants['accessibility_options_json'] = (
        df_restaurants['accessibility_options'].apply(safe_json_loads)
    )

    df_restaurants['wheelchair_accessible_entrance'] = df_restaurants['accessibility_options_json'].apply(lambda d: pick(d, 'wheelchairAccessibleEntrance'))

    df_restaurants.drop(columns=['accessibility_options', 'accessibility_options_json'],
                        inplace=True, errors='ignore')

# %%
if 'parking_options' in df_restaurants.columns:
    df_restaurants['parking_options_json'] = (
        df_restaurants['parking_options'].apply(safe_json_loads)
    )

    df_restaurants['free_street_parking'] = df_restaurants['parking_options_json'].apply(lambda d: pick(d, 'freeStreetParking'))

    df_restaurants.drop(columns=['parking_options', 'parking_options_json'],
                        inplace=True, errors='ignore')

# %%
DISTRICT = "Lichtenberg"
TYPE_OF_FOOD = "Mexican"

# %%
df_restaurants_filtered = df_restaurants[
    (df_restaurants['type_of_food'] == TYPE_OF_FOOD)
]

df_restaurants_filtered.head()
# Out:
#                                                   name type_of_food district  \
# 164  Cantina Mexicana Que Pasa | Mexikanisches Rest...      Mexican    Mitte
# 165                                  El Amigo Taqueria      Mexican    Mitte
# 166                         Taco Loco Cantina Mexicana      Mexican    Mitte
# 167                                            Tex-Mex      Mexican    Mitte
# 168            El Zarape | Mexican Food & Cocktail bar      Mexican    Mitte
#
#      rating  total_ratings           price_level takeout delivery dine_in  \
# 164     4.7         6393.0  PRICE_LEVEL_MODERATE    True    False    True
# 165     4.8         1358.0         NO_PRICE_DATA    True    False    True
# 166     4.4          506.0  PRICE_LEVEL_MODERATE    True     True    True
# 167     4.3         2064.0  PRICE_LEVEL_MODERATE    True    False    True
# 168     4.7          534.0         NO_PRICE_DATA    True     True    True
#
#                                           populartimes  \
# 164  [{'name': 'Monday', 'data': [20, 0, 0, 0, 0, 0...
# 165  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 166  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 167  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
# 168  [{'name': 'Monday', 'data': [0, 0, 0, 0, 0, 0,...
#
#      wheelchair_accessible_entrance  free_street_parking
# 164                           False                False
# 165                            True                False
# 166                           False                False
# 167                           False                False
# 168                           False                False

# %%
# Initialize lists to store the data
days_list = []
hours_list = []
values_list = []

# %%
# Iterate through each restaurant's populartimes
for populartimes in df_restaurants_filtered['populartimes']:
    parsed_data = safe_json_loads(populartimes)

    if parsed_data is not None:
        # Extract data for each day
        for day_data in parsed_data:
            day_name = pick(day_data, 'name')
            hourly_data = pick(day_data, 'data')

            if day_name and hourly_data:
                # Add each hour's data
                for hour, value in enumerate(hourly_data):
                    days_list.append(day_name)
                    hours_list.append(hour)
                    values_list.append(value)

# %%
# Create the dataframe
df_populartimes_temp = pd.DataFrame({
    'day': days_list,
    'hour': hours_list,
    'value': values_list
})

# %%
df_populartimes = (
    df_populartimes_temp
    .groupby(['day', 'hour'])['value']
    .mean()
    .reset_index()
)

df_populartimes.columns = ['day', 'hour', 'value']

# %%
df_populartimes.head()
# Out:
#       day  hour     value
# 0  Friday     0  2.250000
# 1  Friday     1  0.294643
# 2  Friday     2  0.116071
# 3  Friday     3  0.000000
# 4  Friday     4  0.000000

# %%
df_populartimes.shape
# Out:
# (168, 3)

# %%
df_populartimes.dtypes
# Out:
# day       object
# hour       int64
# value    float64
# dtype: object

# %%
df_populartimes.to_csv('/content/drive/MyDrive/Group project/cleaned_data/cleaned_populartimes.csv', index=False, encoding="utf-8-sig")

# %%
df_restaurants.drop(columns=['populartimes'], inplace=True, errors='ignore')

# %%
# Typecheck
df_restaurants.dtypes
# Out:
# name                               object
# type_of_food                       object
# district                           object
# rating                            float64
# total_ratings                     float64
# price_level                        object
# takeout                            object
# delivery                           object
# dine_in                            object
# wheelchair_accessible_entrance       bool
# free_street_parking                  bool
# dtype: object

# %%
df_restaurants['total_ratings'] = df_restaurants['total_ratings'].astype(int)
df_restaurants['dine_in'] = df_restaurants['dine_in'].astype(bool)
df_restaurants['takeout'] = df_restaurants['takeout'].astype(bool)
df_restaurants['delivery'] = df_restaurants['delivery'].astype(bool)

# %%
df_restaurants.dtypes
# Out:
# name                               object
# type_of_food                       object
# district                           object
# rating                            float64
# total_ratings                       int64
# price_level                        object
# takeout                              bool
# delivery                             bool
# dine_in                              bool
# wheelchair_accessible_entrance       bool
# free_street_parking                  bool
# dtype: object

# %%
df_district = pd.read_csv('/content/drive/MyDrive/Group project/data/berlin_district_info.csv')
df_district
# Out:
#                berlin_district  population  area_in_km  pop_density      lat  \
# 0                        Mitte     364.530        3940       10.080  52.5200
# 1     Friedrichshain-Kreuzberg     266.583        2040       14.385  52.5090
# 2                       Pankow     409.453       10322        4.111  52.5667
# 3   Charlottenburg-Wilmersdorf     323.507        6469        5.303  52.5078
# 4                      Spandau     246.257        9188        2.798  52.5511
# 5          Steglitz-Zehlendorf     295.786       10256        3.027  52.4415
# 6         Tempelhof-Schöneberg     337.361        5305        6.708  52.4669
# 7                     Neukölln     307.113        4493        7.345  52.4800
# 8             Treptow-Köpenick     288.802       16773        1.753  52.4400
# 9          Marzahn-Hellersdorf     282.847        6182        4.723  52.5400
# 10                 Lichtenberg     302.726        5212        4.984  52.5150
# 11               Reinickendorf     260.300        8932        3.009  52.5880
#
#         lng
# 0   13.4050
# 1   13.4310
# 2   13.4167
# 3   13.3039
# 4   13.1997
# 5   13.2610
# 6   13.3500
# 7   13.4350
# 8   13.5800
# 9   13.5750
# 10  13.4990
# 11  13.2870

# %%
df_district.rename(columns={'pop_density': 'population_density', 'berlin_district': 'district'}, inplace=True)

# %%
df_district.dtypes
# Out:
# district               object
# population            float64
# area_in_km              int64
# population_density    float64
# lat                   float64
# lng                   float64
# dtype: object

# %%
df_restaurants_district_info = pd.merge(df_restaurants, df_district[['district', 'population_density']], on='district', how='left')

# %%
df_restaurants_district_info.head()
# Out:
#                        name type_of_food district  rating  total_ratings  \
# 0  Coréen Restaurant Berlin       Korean    Mitte     4.2            488
# 1       Mmaah - Eat Korean!       Korean    Mitte     4.7            966
# 2                soopoollim       Korean    Mitte     4.8            412
# 3             YamYam Berlin       Korean    Mitte     4.3           3468
# 4                   Gippeum       Korean    Mitte     4.7            117
#
#             price_level  takeout  delivery  dine_in  \
# 0  PRICE_LEVEL_MODERATE     True     False     True
# 1         NO_PRICE_DATA     True      True     True
# 2         NO_PRICE_DATA     True      True     True
# 3  PRICE_LEVEL_MODERATE     True      True     True
# 4         NO_PRICE_DATA     True      True     True
#
#    wheelchair_accessible_entrance  free_street_parking  population_density
# 0                           False                False               10.08
# 1                            True                False               10.08
# 2                           False                False               10.08
# 3                           False                False               10.08
# 4                           False                False               10.08

# %%
df_restaurants_district_info.to_csv('/content/drive/MyDrive/Group project/cleaned_data/cleaned_restaurants_and_district_info.csv', index=False, encoding="utf-8-sig")

# %%
df_christmas_market = pd.read_csv('/content/drive/MyDrive/Group project/data/christmas_market.csv')
df_christmas_market.head()
# Out:
#     id               bezirk                                             name  \
# 0   58     Treptow-Köpenick                     Winterzauber Weihnachtsmarkt
# 1  181                Mitte                                     Smash Burger
# 2  214                Mitte                                     Weddingmarkt
# 3   61  Steglitz-Zehlendorf  Kunsthandwerklicher Weihnachtsmarkt Mexikoplatz
# 4   97                Mitte               Adventsbasar an der Heilandskirche
#
#                                              strasse    plz  \
# 0                                  Möllhausenufer 30  12555
# 1  Landsberger Allee, Rotes Rathaus, Alexander Platz  10178
# 2                                       Leopoldplatz  13353
# 3                    Mexikoplatz und Bülowstraße 1-8  14163
# 4                                  Thusnelda-Allee 1  10555
#
#                                      von         bis  \
# 0                             01.11.2024  31.12.2024
# 1                             01.11.2024  28.12.2024
# 2  01.12. / 08.12. / 15.12. / 22.12.2024         NaN
# 3           01.12. / 15.12. / 22.12.2024         NaN
# 4                             01.12.2024  01.12.2024
#
#                        veranstalter          oeffnungszeiten  \
# 0      Strandbad Wendenschloss GmbH        12:00 - 20:00 Uhr
# 1                  Mr. Smash Burger  14:00 Uhr bis 23:00 Uhr
# 2     Weddingmarkt - Sabrina Pützer  11:00 Uhr bis 19:00 Uhr
# 3  KUNSTHAND-BERLIN Cornelja Hasler        11:00 - 18:00 Uhr
# 4        Marktzeit - Brigitta Voigt         12:00 -18:00 Uhr
#
#                                  email  \
# 0  info@strandbad-wendenschloss.berlin
# 1                 vivien-selimi@gmx.de
# 2         weddingkulturmarkt@gmail.com
# 3             info@kunsthand-berlin.de
# 4                  marktzeit@posteo.de
#
#                                        w3  \
# 0  https://strandbad-wendenschloss.berlin
# 1                                       /
# 2           https://www.wedding-markt.de/
# 3            https://kunsthand-berlin.de/
# 4           https://www.marktzeit.berlin/
#
#                                          bemerkungen
# 0                                                  /
# 1                                                  /
# 2  Weddingmarkt wird Weihnachtsmarkt. An allen 4....
# 3  Es werden nur handgefertigte Objekte kleiner A...
# 4        Adventsmarkt findet nur am 1. Advent statt.

# %%
df_christmas_market['bezirk'].value_counts()
# Out:
# bezirk
# Steglitz-Zehlendorf           12
# Charlottenburg-Wilmersdorf    11
# Mitte                          9
# Brandenburg                    8
# Tempelhof-Schöneberg           7
# Pankow                         7
# Treptow-Köpenick               6
# Marzahn-Hellersdorf            4
# Reinickendorf                  3
# Friedrichshain-Kreuzberg       3
# Neukölln                       3
# Spandau                        2
# Name: count, dtype: int64

# %%
df_christmas_market.to_csv('/content/drive/MyDrive/Group project/cleaned_data/cleaned_christmas_market.csv', index=False, encoding="utf-8-sig")

# %%
df_street_food_and_folk_festivals = pd.read_csv('/content/drive/MyDrive/Group project/data/street_food_and_folk_festivals.csv')
df_street_food_and_folk_festivals.head()
# Out:
#     id                bezirk  \
# 0   19  Tempelhof-Schöneberg
# 1   16                 Mitte
# 2  142         Reinickendorf
# 3   73   Marzahn-Hellersdorf
# 4  169      Treptow-Köpenick
#
#                                          bezeichnung  \
# 0  650 Jahre Lichtenrade rund um den Lichtenrader...
# 1         30 Jahre UMWELTFESTIVAL – jetzt erst recht
# 2                             Gorkistraßenfest Tegel
# 3                              Biesdorfer Blütenfest
# 4                                  Köpenicker Herbst
#
#                                      strasse      plz         von         bis  \
# 0                            Alt-Lichtenrade  12309.0  01.05.2025  04.05.2025
# 1  Straße des 17. Juni, am Brandenburger Tor  10117.0  01.06.2025         NaN
# 2                          Gorkistraße 11/21  13507.0  01.08.2025  02.08.2025
# 3      Schlosspark Biesdorf, Alt-Biesdorf 55  12683.0  02.05.2025  04.05.2025
# 4                        Luisenhain Köpenick  12555.0  02.10.2025  05.10.2025
#
#                                                 zeit  \
# 0  Do/Fr/Sa 12:00 bis 23:00 Uhr \nSo 12:00 bis 20...
# 1                                11:00 bis 18:00 Uhr
# 2                        Fr 15-22 Uhr \nSa 12-22 Uhr
# 3             Fr 16-22 Uhr Sa 12-22 Uhr So 12-18 Uhr
# 4             Fr 12-22 Uhr Sa 12-22 Uhr So 12-20 Uhr
#
#                  veranstalter                                  mail  \
# 0  Family &amp; Friends e. V.  stadtkultur@family-and-friends-ev.de
# 1       GRÜNE LIGA Berlin e.V                info@umweltfestival.de
# 2           Hauptstadt Kultur        info@juettner-entertainment.de
# 3           Hauptstadt Kultur        info@juettner-entertainment.de
# 4           Hauptstadt Kultur        info@juettner-entertainment.de
#
#                                                  www  \
# 0  https://www.family-and-friends-ev.de/1-4-mai-2...
# 1                     https://www.umweltfestival.de/
# 2                https://www.hauptstadtkultur.berlin
# 3                https://www.hauptstadtkultur.berlin
# 4                https://www.hauptstadtkultur.berlin
#
#                   barrierefreiheit  \
# 0  Ja, findet auf der Straße statt
# 1                               Ja
# 2                               Ja
# 3                               Ja
# 4                               Ja
#
#                                          bemerkungen
# 0  Wo kann man 650 Jahre Lichtenrade besser feier...
# 1  Das ganze Veranstaltungsgelände ist ebenerdig ...
# 2  Mit dem Gorkistraßenfest wird eine neue Verans...
# 3  Neben dem musikalischen Rahmenprogramm erwarte...
# 4  Spaß für Jung und Alt mit Spiel und Fahrgeschä...

# %%
#Drop unnecessary columns
df_street_food_and_folk_festivals.drop(columns=['id', 'bezeichnung', 'strasse', 'plz', 'veranstalter',	'mail',	'www', 'bemerkungen'], inplace=True)
df_street_food_and_folk_festivals.head()
# Out:
#                  bezirk         von         bis  \
# 0  Tempelhof-Schöneberg  01.05.2025  04.05.2025
# 1                 Mitte  01.06.2025         NaN
# 2         Reinickendorf  01.08.2025  02.08.2025
# 3   Marzahn-Hellersdorf  02.05.2025  04.05.2025
# 4      Treptow-Köpenick  02.10.2025  05.10.2025
#
#                                                 zeit  \
# 0  Do/Fr/Sa 12:00 bis 23:00 Uhr \nSo 12:00 bis 20...
# 1                                11:00 bis 18:00 Uhr
# 2                        Fr 15-22 Uhr \nSa 12-22 Uhr
# 3             Fr 16-22 Uhr Sa 12-22 Uhr So 12-18 Uhr
# 4             Fr 12-22 Uhr Sa 12-22 Uhr So 12-20 Uhr
#
#                   barrierefreiheit
# 0  Ja, findet auf der Straße statt
# 1                               Ja
# 2                               Ja
# 3                               Ja
# 4                               Ja

# %%
#change column names
df_street_food_and_folk_festivals.columns = ["district", "from", "to", "time", "entrance"]
df_street_food_and_folk_festivals['district'].value_counts()
# Out:
# district
# Reinickendorf                   12
# Tempelhof-Schöneberg             8
# Treptow-Köpenick                 8
# Charlottenburg-Wilmersdorf       6
# Steglitz-Zehlendorf              6
# Pankow                           6
# Lichtenberg                      5
# Mitte                            4
# Marzahn-Hellersdorf              4
# Neukölln                         4
# Spandau                          2
# Brandenburg                      1
# Charlottenburg - Wilmersdorf     1
# Friedrichshain-Kreuzberg         1
# Name: count, dtype: int64

# %%
df_street_food_and_folk_festivals.to_csv('/content/drive/MyDrive/Group project/cleaned_data/cleaned_street_food_and_folk_festivals.csv', index=False, encoding="utf-8-sig")

# %%
df_companies = pd.read_csv('/content/drive/MyDrive/Group project/data/companies.csv')
df_companies.head()
# Out:
#                             id                             name district
# 0  ChIJLyG1ae5RqEcRV7CDd2ppmHA                      Afilio GmbH    Mitte
# 1  ChIJIb_c4-tRqEcRXYbvOFkDjYw               IBM iX Berlin GmbH    Mitte
# 2  ChIJNZGrWOxRqEcR1cy2vmMmUsU                      HERE Berlin    Mitte
# 3  ChIJl3hWxLlRqEcRtwCZURdqxFo  Everstores Technologies GmbH HQ    Mitte
# 4  ChIJO23u5jdOqEcRHiuo9oNkDBk                  Sensorberg GmbH    Mitte

# %%
df_companies_grouped_by_district = df_companies.groupby('district').size().reset_index(name='count')
df_companies_grouped_by_district.sort_values(by='count', ascending=False)
# Out:
#                       district  count
# 4                        Mitte   1568
# 0   Charlottenburg-Wilmersdorf   1344
# 6                       Pankow   1000
# 9          Steglitz-Zehlendorf    900
# 10        Tempelhof-Schöneberg    846
# 1     Friedrichshain-Kreuzberg    748
# 11            Treptow-Köpenick    719
# 5                     Neukölln    657
# 7                Reinickendorf    504
# 3          Marzahn-Hellersdorf    465
# 2                  Lichtenberg    449
# 8                      Spandau    444

# %%
df_companies_grouped_by_district.to_csv('/content/drive/MyDrive/Group project/cleaned_data/cleaned_companies_grouped_by_district.csv', index=False, encoding="utf-8-sig")

# %%
df_restaurants_district_info.describe()
# Out:
#             rating  total_ratings  population_density
# count  3412.000000    3412.000000         3412.000000
# mean      4.496805     842.134525            6.516986
# std       0.348955    1589.535931            3.636017
# min       1.000000       1.000000            1.753000
# 25%       4.400000     181.000000            3.027000
# 50%       4.500000     468.500000            5.303000
# 75%       4.700000     946.000000           10.080000
# max       5.000000   36921.000000           14.385000
